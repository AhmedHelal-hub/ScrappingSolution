# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import json

# %%
# URL of the page to scrape
url = "https://www.bol.com/nl/nl/l/audio-hifi/10714/"

# %%
# Send a GET request to the URL
response = requests.get(url)

# %%
# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Find the elements containing the products
    products = soup.find_all('div', class_='product-item__content')
    
    # List to store the data
    data = []

    # Iterate over the products and extract the required information
    for product in products:
        tracking_event_tag = product.find('wsp-analytics-tracking-event')
        
        # Check if tracking_event_tag is found
        if not tracking_event_tag:
            continue
        
        # Extract the 'data-config' attribute
        data_config = tracking_event_tag['data-config']
        
        # Parse the JSON data
        config_object = json.loads(data_config)
        
        # Get the 'product_id'
        product_id = config_object['product_id']
        
        title_tag = product.find('a', class_='product-title px_list_page_product_click list_page_product_tracking_target')
        title = title_tag.get_text(strip=True) if title_tag else 'N/A'
        
        brand_tag = product.find('ul', class_='product-creator')
        brand = brand_tag.get_text(strip=True) if brand_tag else 'N/A'
        
        # Find the outer div tag
        outer_div = product.find('div', class_='u-mb--xs')
        
        # Check if outer_div is found
        if not outer_div:
            continue
        
        # Extract the rating and number of reviews
        aria_label = outer_div['aria-label']
        rating = aria_label.split('Gemiddeld')[1].split('van de 5 sterren')[0].strip()
        
        number_of_reviews = aria_label.split('uit')[1].split('reviews')[0].strip()
        n_reviews = number_of_reviews
        
        url = 'https://www.bol.com' + title_tag['href'] if title_tag else 'N/A'
        
        price_span = product.find('span', class_='promo-price')
        
        # Check if price_span is found
        if not price_span:
            continue
        
        # Extract the integer part of the price and strip whitespace
        integer_part = price_span.contents[0].strip().replace('.-', '')

        # Extract the fractional part of the price, if it exists, and strip whitespace
        fraction_sup = price_span.find('sup', class_='promo-price__fraction')
        fraction_part = fraction_sup.text.strip() if fraction_sup and fraction_sup.text.strip() else '00'

        # Combine the parts to get the full price as a string
        price_str = f"{integer_part}.{fraction_part}"

        # Convert the price to a float
        try:
            price_float = float(price_str)
        except ValueError:
            # Handle cases where price_str might still be malformed
            if integer_part and not fraction_part.isdigit():
                price_str = f"{integer_part}.00"
                price_float = float(price_str)
        
        price = price_float
        
        currency = 'EUR'  # Assuming the currency is EUR 
        
        category_name = 'Audio & HiFi'  # As per the given category in the URL

        # Append the data to the list
        data.append([product_id, title, brand, rating, n_reviews, url, price, currency, category_name])

    # Create a DataFrame from the data
    df = pd.DataFrame(data, columns=['PID', 'Title', 'Brand', 'Rating', 'N_Reviews', 'URL', 'Price', 'Currency', 'Category_Name'])

    # Save the DataFrame to a CSV file
    df.to_csv('products.csv', index=False)
    
    print('Data has been successfully saved to products.csv')
else:
    print('Failed. Status code:', response.status_code)
# Out:
# Data has been successfully saved to products.csv

# %%
df
# Out:
#                  PID                                              Title  \
# 0   9300000174719290  Carplay Scherm - Touchscreen - Navigatiesystee...
# 1   9300000161469652  Samsung koptelefoon EO-EG920BW Hybrid earbuds wit
# 2   9200000066399178                Pioneer PD-10AE - CD-speler - Zwart
# 3   9200000074953095  Pioneer GM-A6704 Autoversterker 4 kanaals - 10...
# 4   9300000020209238  JBL Tune 660NC Zwart - Draadloze on-ear Noise ...
# 5   9200000108340791         Apple AirPods 2 - met reguliere oplaadcase
# 6   9300000161136600  Apple AirPods Pro 2 - met MagSafe oplaadcase (...
# 7   9200000108639206     JBL Flip 5 Zwart - Draagbare Bluetooth Speaker
# 8   9300000155640894  JBL Tune 235NC TWS - Volledig Draadloze Oordop...
# 9   9200000065666274            Apple EarPods met lightning aansluiting
# 10  9300000123041487         Apple AirPods 3 - met reguliere oplaadcase
# 11  9300000101422099  JBL Charge Essential 2 - Bluetooth Speaker - Z...
# 12  9300000161136530                              Apple EarPods (USB-C)
# 13  9300000149873801  JBL Tune 770NC - Draadloze over-ear koptelefoo...
# 14  9300000110615717   JBL Flip Essential 2 - Bluetooth Speaker - Zwart
# 15  9300000006173040  Sony WH-1000XM4 - Draadloze over-ear koptelefo...
# 16  9300000009699346  JBL PartyBox 310 - Bluetooth Party Speaker - Z...
# 17  9300000044042255  JBL Tune 760NC - Draadloze over-ear koptelefoo...
# 18  9300000150990652  JBL Tune Buds - Volledig Draadloze Oordopjes M...
# 19  9300000001023970  Wegman Bluetooth FM Transmitter - Autolader - ...
# 20  9300000009699479  JBL JR310BT Kids - Draadloze on-ear koptelefoo...
# 21  9300000161188289                  Samsung Galaxy Buds FE - Graphite
#
#          Brand Rating N_Reviews  \
# 0   The Useful    3.6        17
# 1      Samsung    4.0         1
# 2      Pioneer    4.8        12
# 3      Pioneer    5.0         1
# 4          JBL    4.3       123
# 5        Apple    4.6      1998
# 6        Apple    4.4       325
# 7          JBL    4.6       531
# 8          JBL    3.8       439
# 9        Apple    3.3       757
# 10       Apple    4.2       224
# 11         JBL    4.7       217
# 12       Apple    4.1        23
# 13         JBL    4.5        83
# 14         JBL    4.7       166
# 15        Sony    4.4       421
# 16         JBL    4.8       134
# 17         JBL    4.2       234
# 18         JBL    3.8        13
# 19      Wegman    4.7      1326
# 20         JBL    4.5       343
# 21     Samsung    4.1        50
#
#                                                   URL   Price Currency  \
# 0   https://www.bol.com/nl/nl/p/carplay-scherm-tou...   84.95      EUR
# 1   https://www.bol.com/nl/nl/p/samsung-stereo-hea...   10.22      EUR
# 2   https://www.bol.com/nl/nl/p/pioneer-pd-10ae-cd...  209.99      EUR
# 3   https://www.bol.com/nl/nl/p/pioneer-gm-a6704-a...  139.00      EUR
# 4   https://www.bol.com/nl/nl/p/jbl-tune-660nc-zwa...   60.00      EUR
# 5   https://www.bol.com/nl/nl/p/apple-airpods-2-in...  127.00      EUR
# 6   https://www.bol.com/nl/nl/p/mqd83am-a-airpods-...  247.00      EUR
# 7   https://www.bol.com/nl/nl/p/jbl-flip-5-zwart-d...   79.95      EUR
# 8   https://www.bol.com/nl/nl/p/jbl-tune-235nc-tws...   58.00      EUR
# 9   https://www.bol.com/nl/nl/p/apple-earpods-met-...   19.75      EUR
# 10  https://www.bol.com/nl/nl/p/apple-airpods-3-me...  189.00      EUR
# 11  https://www.bol.com/nl/nl/p/jbl-charge-essenti...  103.00      EUR
# 12  https://www.bol.com/nl/nl/p/earpods/9300000161...   19.35      EUR
# 13  https://www.bol.com/nl/nl/p/jbl-tune-770nc-dra...   78.00      EUR
# 14  https://www.bol.com/nl/nl/p/jbl-flip-essential...   81.99      EUR
# 15  https://www.bol.com/nl/nl/p/sony-wh-1000xm4-dr...  229.00      EUR
# 16  https://www.bol.com/nl/nl/p/jbl-partybox-310-b...  388.00      EUR
# 17  https://www.bol.com/nl/nl/p/jbl-tune-760nc-dra...   65.00      EUR
# 18  https://www.bol.com/nl/nl/p/jbl-tune-buds-voll...   80.00      EUR
# 19  https://www.bol.com/nl/nl/p/wegman-bluetooth-f...   24.95      EUR
# 20  https://www.bol.com/nl/nl/p/jbl-jr310bt-kids-d...   35.99      EUR
# 21  https://www.bol.com/nl/nl/p/samsung-galaxy-bud...   64.95      EUR
#
#    Category_Name
# 0   Audio & HiFi
# 1   Audio & HiFi
# 2   Audio & HiFi
# 3   Audio & HiFi
# 4   Audio & HiFi
# 5   Audio & HiFi
# 6   Audio & HiFi
# 7   Audio & HiFi
# 8   Audio & HiFi
# 9   Audio & HiFi
# 10  Audio & HiFi
# 11  Audio & HiFi
# 12  Audio & HiFi
# 13  Audio & HiFi
# 14  Audio & HiFi
# 15  Audio & HiFi
# 16  Audio & HiFi
# 17  Audio & HiFi
# 18  Audio & HiFi
# 19  Audio & HiFi
# 20  Audio & HiFi
# 21  Audio & HiFi
