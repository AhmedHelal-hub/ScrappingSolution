# %%
import requests
from parsel import Selector
import pandas as pd
import json

# %%
# URL of the page to scrape
url = "https://www.bol.com/nl/nl/l/audio-hifi/10714/"

# %%
# Send a GET request to the URL
response = requests.get(url)

# %%
# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content using Parsel
    selector = Selector(response.text)
    
    # Find the elements containing the products
    products = selector.xpath('//div[@class="product-item__content"]')
    
    # List to store the data
    data = []

    # Iterate over the products and extract the required information
    for product in products:
        tracking_event_tag = product.xpath('.//wsp-analytics-tracking-event/@data-config').get()
        
        # Check if tracking_event_tag is found
        if not tracking_event_tag:
            continue
        
        # Extract the 'data-config' attribute
        data_config = tracking_event_tag
        
        # Parse the JSON data
        config_object = json.loads(data_config)
        
        # Get the 'product_id'
        product_id = config_object['product_id']
        
        title_tag = product.xpath('.//a[@class="product-title px_list_page_product_click list_page_product_tracking_target"]/text()').get()
        title = title_tag.strip() if title_tag else 'N/A'
        
        brand_tag = product.xpath('.//ul[@class="product-creator"]/text()').get()
        brand = brand_tag.strip() if brand_tag else 'N/A'
        
        # Find the outer div tag
        outer_div = product.xpath('.//div[@class="u-mb--xs"]')
        
        # Check if outer_div is found
        if not outer_div:
            continue
        
        # Extract the rating and number of reviews
        aria_label = outer_div.xpath('./@aria-label').get()
        rating = aria_label.split('Gemiddeld')[1].split('van de 5 sterren')[0].strip() if 'Gemiddeld' in aria_label else 'N/A'
        
        number_of_reviews = aria_label.split('uit')[1].split('reviews')[0].strip() if 'uit' in aria_label else 'N/A'
        n_reviews = number_of_reviews
        
        url_tag = product.xpath('.//a[@class="product-title px_list_page_product_click list_page_product_tracking_target"]/@href').get()
        url = 'https://www.bol.com' + url_tag if url_tag else 'N/A'
        
        price_span = product.xpath('.//span[@class="promo-price"]')
        
        # Check if price_span is found
        if not price_span:
            continue
        
        # Extract the integer part of the price and strip whitespace
        integer_part = price_span.xpath('normalize-space(text())').get().replace('.-', '')

        # Extract the fractional part of the price, if it exists, and strip whitespace
        fraction_sup = price_span.xpath('.//sup[@class="promo-price__fraction"]/text()').get()
        fraction_part = fraction_sup.strip() if fraction_sup else '00'

        # Combine the parts to get the full price as a string
        price_str = f"{integer_part}.{fraction_part}"

        # Convert the price to a float
        try:
            price_float = float(price_str)
        except ValueError:
            # Handle cases where price_str might still be malformed
            if integer_part and not fraction_part.isdigit():
                price_str = f"{integer_part}.00"
                price_float = float(price_str)
        
        price = price_float
        
        currency = 'EUR'  # Assuming the currency is EUR 
        
        category_name = 'Audio & HiFi'  # As per the given category in the URL

        # Append the data to the list
        data.append([product_id, title, brand, rating, n_reviews, url, price, currency, category_name])

    # Create a DataFrame from the data
    df = pd.DataFrame(data, columns=['PID', 'Title', 'Brand', 'Rating', 'N_Reviews', 'URL', 'Price', 'Currency', 'Category_Name'])

    # Save the DataFrame to a CSV file
    df.to_csv('products_xpath.csv', index=False)
    
    print('Data has been successfully saved to product_xpath.csv')
else:
    print('Failed. Status code:', response.status_code)
# Out:
# Data has been successfully saved to product_xpath.csv

# %%
df
# Out:
#                  PID                                              Title Brand  \
# 0   9300000174719290  Carplay Scherm - Touchscreen - Navigatiesystee...
# 1   9300000161136530                              Apple EarPods (USB-C)
# 2   9300000025109728  JBL Tune 510BT - Draadloze on-ear koptelefoon ...
# 3   9200000074953095  Pioneer GM-A6704 Autoversterker 4 kanaals - 10...
# 4   9200000066399178                Pioneer PD-10AE - CD-speler - Zwart
# 5   9300000020209238  JBL Tune 660NC Zwart - Draadloze on-ear Noise ...
# 6   9200000108340791         Apple AirPods 2 - met reguliere oplaadcase
# 7   9300000161136600  Apple AirPods Pro 2 - met MagSafe oplaadcase (...
# 8   9200000108639206     JBL Flip 5 Zwart - Draagbare Bluetooth Speaker
# 9   9200000065666274            Apple EarPods met lightning aansluiting
# 10  9300000123041487         Apple AirPods 3 - met reguliere oplaadcase
# 11  9200000101861365  Rolfstone Nova Sport - Volledig Draadloze Oord...
# 12  9300000101422099  JBL Charge Essential 2 - Bluetooth Speaker - Z...
# 13  9300000149873801  JBL Tune 770NC - Draadloze over-ear koptelefoo...
# 14  9300000006173040  Sony WH-1000XM4 - Draadloze over-ear koptelefo...
# 15  9300000009699346  JBL PartyBox 310 - Bluetooth Party Speaker - Z...
# 16  9300000110615717   JBL Flip Essential 2 - Bluetooth Speaker - Zwart
# 17  9300000044042255  JBL Tune 760NC - Draadloze over-ear koptelefoo...
# 18  9300000024247548  Rolfstone Focus Pro - Koptelefoon - Active Noi...
# 19  9300000009699479  JBL JR310BT Kids - Draadloze on-ear koptelefoo...
# 20  9300000001023970  Wegman Bluetooth FM Transmitter - Autolader - ...
# 21  9300000150990652  JBL Tune Buds - Volledig Draadloze Oordopjes M...
# 22  9300000161188289                  Samsung Galaxy Buds FE - Graphite
# 23  9300000114127731  Samsung Galaxy Buds 2 Pro - Draadloze oordopje...
#
#    Rating N_Reviews                                                URL  \
# 0     3.6        17  https://www.bol.com/nl/nl/p/carplay-scherm-tou...
# 1     4.1        24  https://www.bol.com/nl/nl/p/earpods/9300000161...
# 2     4.4       484  https://www.bol.com/nl/nl/p/jbl-tune-510bt-dra...
# 3     5.0         1  https://www.bol.com/nl/nl/p/pioneer-gm-a6704-a...
# 4     4.8        12  https://www.bol.com/nl/nl/p/pioneer-pd-10ae-cd...
# 5     4.4       128  https://www.bol.com/nl/nl/p/jbl-tune-660nc-zwa...
# 6     4.6      1999  https://www.bol.com/nl/nl/p/apple-airpods-2-in...
# 7     4.4       325  https://www.bol.com/nl/nl/p/mqd83am-a-airpods-...
# 8     4.6       531  https://www.bol.com/nl/nl/p/jbl-flip-5-zwart-d...
# 9     3.3       757  https://www.bol.com/nl/nl/p/apple-earpods-met-...
# 10    4.2       224  https://www.bol.com/nl/nl/p/apple-airpods-3-me...
# 11    4.3      1293  https://www.bol.com/nl/nl/p/rolfstone-nova-spo...
# 12    4.7       217  https://www.bol.com/nl/nl/p/jbl-charge-essenti...
# 13    4.4        84  https://www.bol.com/nl/nl/p/jbl-tune-770nc-dra...
# 14    4.4       421  https://www.bol.com/nl/nl/p/sony-wh-1000xm4-dr...
# 15    4.8       134  https://www.bol.com/nl/nl/p/jbl-partybox-310-b...
# 16    4.7       166  https://www.bol.com/nl/nl/p/jbl-flip-essential...
# 17    4.2       234  https://www.bol.com/nl/nl/p/jbl-tune-760nc-dra...
# 18    4.4       259  https://www.bol.com/nl/nl/p/rolfstone-focus-pr...
# 19    4.5       343  https://www.bol.com/nl/nl/p/jbl-jr310bt-kids-d...
# 20    4.7      1326  https://www.bol.com/nl/nl/p/wegman-bluetooth-f...
# 21    3.8        13  https://www.bol.com/nl/nl/p/jbl-tune-buds-voll...
# 22    4.1        50  https://www.bol.com/nl/nl/p/samsung-galaxy-bud...
# 23    4.1       108  https://www.bol.com/nl/nl/p/samsung-galaxy-bud...
#
#      Price Currency Category_Name
# 0    84.95      EUR  Audio & HiFi
# 1    19.35      EUR  Audio & HiFi
# 2    36.00      EUR  Audio & HiFi
# 3   139.00      EUR  Audio & HiFi
# 4   219.99      EUR  Audio & HiFi
# 5    60.00      EUR  Audio & HiFi
# 6   127.00      EUR  Audio & HiFi
# 7   247.58      EUR  Audio & HiFi
# 8    99.00      EUR  Audio & HiFi
# 9    20.99      EUR  Audio & HiFi
# 10  189.00      EUR  Audio & HiFi
# 11   79.00      EUR  Audio & HiFi
# 12  103.00      EUR  Audio & HiFi
# 13   78.00      EUR  Audio & HiFi
# 14  229.00      EUR  Audio & HiFi
# 15  426.00      EUR  Audio & HiFi
# 16   79.00      EUR  Audio & HiFi
# 17   65.00      EUR  Audio & HiFi
# 18  119.00      EUR  Audio & HiFi
# 19   47.99      EUR  Audio & HiFi
# 20   24.95      EUR  Audio & HiFi
# 21   79.00      EUR  Audio & HiFi
# 22   64.95      EUR  Audio & HiFi
# 23  119.60      EUR  Audio & HiFi
